# %% [markdown]
# # Interactions - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll explore interactions in the Boston Housing data set.

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Understand what interactions are
# - Understand how to accommodate for interactions in regression

# %% [markdown]
# ## Build a baseline model

# %% [markdown]
# You'll use a couple of built-in functions, which we imported for you below.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Import the Boston data set using `load_boston()`. We won't bother to preprocess the data in this lab. If you still want to build a model in the end, you can do that, but this lab will just focus on finding meaningful insights in interactions and how they can improve $R^2$ values.

# %%
regression = LinearRegression()
boston = load_boston()

# %% [markdown]
# Create a baseline model which includes all the variables in the Boston housing data set to predict the house prices. The use 10-fold cross-validation and report the mean $R^2$ value as the baseline $R^2$.

# %%
boston_features = pd.DataFrame(boston.data, columns = boston.feature_names)
boston_features_and_target = boston_features.copy()
boston_features_and_target['target'] = boston.target

# %%
linreg = LinearRegression()
linreg.fit(boston_features, boston.target)
crossvalidation = KFold(n_splits=10, shuffle=True, random_state=1)
baseline = np.mean(cross_val_score(linreg, boston_features, y=boston.target, cv=crossvalidation, scoring='r2'))

# %%
baseline
# Out:
# 0.7189415144723069

# %% [markdown]
# ## See how interactions improve your baseline

# %% [markdown]
# Next, create all possible combinations of interactions, loop over them and add them to the baseline model one by one to see how they affect the R^2. We'll look at the 3 interactions which have the biggest effect on our R^2, so print out the top 3 combinations.
#
# You will create a for loop to loop through all the combinations of 2 predictors. You can use `combinations` from itertools to create a list of all the pairwise combinations. To find more info on how this is done, have a look [here](https://docs.python.org/2/library/itertools.html).

# %%
from itertools import combinations
combinations = list(combinations(boston.feature_names, 2))

# %%
## code to find top 3 interactions by R^2 value here
interactions = []
for combo in combinations:
    linreg = LinearRegression()
    X = pd.DataFrame(boston.data, columns = boston.feature_names)
    y = boston.target
    X_interact = X.copy()
    X_interact["combo"] = X[combo[0]] * X[combo[1]]
    crossvalidation = KFold(n_splits=10, shuffle=True, random_state=1)
    baseline = np.mean(cross_val_score(linreg, X_interact, y=boston.target, cv=crossvalidation, scoring='r2'))
    interactions.append({'Combination': combo, "r_squared": baseline})

# %%
interactions_sorted = sorted(interactions, key=lambda k: k['r_squared'])
interactions_sorted[-3:]
# Out:
# [{'Combination': ('RM', 'RAD'), 'r_squared': 0.7681911936798653},
#  {'Combination': ('RM', 'TAX'), 'r_squared': 0.7750384950244524},
#  {'Combination': ('RM', 'LSTAT'), 'r_squared': 0.7864767111617036}]

# %% [markdown]
# ## Look at the top 3 interactions: "RM" as a confounding factor

# %% [markdown]
# The top three interactions seem to involve "RM", the number of rooms as a confounding variable for all of them. Let's have a look at interaction plots for all three of them. This exercise will involve:
#
# - splitting our data up in 3 groups: one for houses with a few rooms, one for houses with a "medium" amount of rooms, one for a high amount of rooms.
# - Create a function `build_interaction_rm`. This function takes an argument `varname` (which can be set equal to the column name as a string) and a column `description` (which describes the variable or varname, to be included on the x-axis of the plot). The function outputs a plot that uses "RM" as a confounding factor.

# %% [markdown]
# We split the data set for high, medium and low amount of rooms for you.

# %%
rm = np.asarray(boston_features_and_target[["RM"]]).reshape(len(boston_features_and_target[["RM"]]))

# %%
high_rm = boston_features_and_target[rm > np.percentile(rm, 67)]
med_rm = boston_features_and_target[(rm > np.percentile(rm, 33)) & (rm <= np.percentile(rm, 67))]
low_rm = boston_features_and_target[rm <= np.percentile(rm, 33)]

# %% [markdown]
# Create `build_interaction_rm`.

# %%
def build_interaction_rm(varname):
    h_reg = LinearRegression()
    m_reg = LinearRegression()
    l_reg = LinearRegression()
    
    h_reg.fit(high_rm[varname].values.reshape(-1, 1), high_rm["target"])
    m_reg.fit(med_rm[varname].values.reshape(-1, 1), med_rm["target"])
    l_reg.fit(low_rm[varname].values.reshape(-1, 1), low_rm["target"])
    print(h_reg.coef_)
    print(m_reg.coef_)
    print(l_reg.coef_)
    
    h_pred = h_reg.predict(high_rm[varname].values.reshape(-1, 1))
    m_pred = m_reg.predict(med_rm[varname].values.reshape(-1, 1))
    l_pred = l_reg.predict(low_rm[varname].values.reshape(-1, 1))
    
    plt.figure(figsize=(12,7))
    plt.scatter(high_rm[varname], high_rm['target'])
    plt.scatter(med_rm[varname], med_rm['target'])
    plt.scatter(low_rm[varname], low_rm['target'])
    
    plt.plot(high_rm[varname], h_pred)
    plt.plot(med_rm[varname], m_pred)
    plt.plot(low_rm[varname], l_pred)
    
    plt.ylabel("house value")
    plt.xlabel(varname)
    plt.show()

# %% [markdown]
# Next, use build_interaction_rm with the three variables that came out with the highest effect on $R^2$

# %%
# first plot
build_interaction_rm('RAD')
# Out:
# [-0.66803793]
# [-0.24276834]
# [-0.17393132]

# %%
# second plot
build_interaction_rm('TAX')
# Out:
# [-0.03708037]
# [-0.01431143]
# [-0.01166035]

# %%
build_interaction_rm("LSTAT")
# third plot
# Out:
# [-1.46614438]
# [-0.67588205]
# [-0.51981339]

# %% [markdown]
# ## Build a final model including all three interactions at once

# %% [markdown]
# Use 10-fold crossvalidation.

# %%
# code here
linreg = LinearRegression()
crossvalidation = KFold(n_splits=10, shuffle=True, random_state=1)
boston_features['RM * TAX'] = boston_features['RM'] * boston_features['TAX']
boston_features['RM * LSTAT'] = boston_features['RM'] * boston_features['LSTAT']
boston_features['RM * RAD'] = boston_features['RM'] * boston_features['RAD']

final_model = np.mean(cross_val_score(linreg, boston_features, boston.target, scoring="r2", cv=crossvalidation))

# %%
final_model
# Out:
# 0.785308416901656

# %% [markdown]
# Our $R^2$ has increased considerably! Let's have a look in statsmodels to see if all these interactions are significant.

# %%
import statsmodels.api as sm
df_inter_sm = sm.add_constant(boston_features)
model = sm.OLS(y,df_inter_sm)
results = model.fit()

results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.815
# Model:                            OLS   Adj. R-squared:                  0.809
# Method:                 Least Squares   F-statistic:                     134.4
# Date:                Thu, 06 Dec 2018   Prob (F-statistic):          2.83e-167
# Time:                        16:23:02   Log-Likelihood:                -1413.8
# No. Observations:                 506   AIC:                             2862.
# Df Residuals:                     489   BIC:                             2933.
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -14.8281      7.426     -1.997      0.046     -29.419      -0.237
# ...

# %% [markdown]
# What is your conclusion here?

# %%
# formulate your conclusion

# %% [markdown]
# ## Summary

# %% [markdown]
# You now understand how to include interaction effects in your model!
